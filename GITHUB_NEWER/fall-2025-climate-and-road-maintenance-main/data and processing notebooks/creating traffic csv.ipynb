# %% [markdown]
# # Imported traffic csv notebook
#
# This is an older traffic-processing notebook from `GITHUB_NEWER`. It is kept for reference.

# %%
import pandas as pd

traffic_1 = pd.read_csv("traffic_1.csv")

# %%
traffic_1['SegmentID'].nunique()
# Out:
# 1364

# %%
traffic_2 = pd.read_csv("traffic_2.csv")

# %%
traffic_2['SegmentID'].nunique()
# Out:
# 1211

# %%
traffic_1[traffic_1['SegmentID'] == 155613]
# Out:
#        Unnamed: 0  RequestID    Boro    Yr  M   D  HH  MM  Vol  SegmentID  \
# 0               0      22562  Queens  2016  5   8   8  45  260     155613
# 1               1      22562  Queens  2016  5   8   9   0  243     155613
# 2               2      22562  Queens  2016  5   8   9  15  245     155613
# 3               3      22562  Queens  2016  5   8   9  30  304     155613
# 4               4      22562  Queens  2016  5   8   9  45  312     155613
# ...           ...        ...     ...   ... ..  ..  ..  ..  ...        ...
# 10381       17843      22562  Queens  2016  5  15  22  45  216     155613
# 10382       17844      22562  Queens  2016  5  15  23   0  167     155613
# 10383       17845      22562  Queens  2016  5  15  23  15  174     155613
# 10384       17846      22562  Queens  2016  5  15  23  30  138     155613
# 10385       17847      22562  Queens  2016  5  15  23  45  116     155613
#
#                                              WktGeom            street  \
# ...
