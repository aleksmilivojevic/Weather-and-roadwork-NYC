# %% [markdown]
# # Archived GBM scratch work
#
# This is old scratch work kept for reference. It is not part of the main workflow.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from yfinance) (2.3.4)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 318.4 kB/s  0:00:02a 0:00:04
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.7->yfinance)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/aleksandarmilivojevic/Downloads/python_folder_vs_code/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 635.2 kB/s  0:00:05 eta 0:00:01
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl (181 kB)
# Using cached frozendict-2.4.6-py312-none-any.whl (16 kB)
# Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15636 sha256=0642e808064c6a90e12823e2d7e279bb0adaff2a3754126d736d221f57f29f41
#   Stored in directory: /Users/aleksandarmilivojevic/Library/Caches/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.2-cp312-cp312-macosx_10_9_universal2.whl size=438034 sha256=0f09801a47c3de29024f74067d0abead997b7310a91e0b97cf7407d1be66f826
#   Stored in directory: /Users/aleksandarmilivojevic/Library/Caches/pip/wheels/d1/df/a9/0202b051c65b11c992dd6db9f2babdd2c44ec7d35d511be5d3
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, urllib3, typing-extensions, soupsieve, pycparser, protobuf, idna, frozendict, charset_normalizer, certifi, requests, cffi, beautifulsoup4, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [yfinance]/17 [curl_cffi]ensions]
# Successfully installed beautifulsoup4-4.14.2 certifi-2025.10.5 cffi-2.0.0 charset_normalizer-3.4.4 curl_cffi-0.13.0 frozendict-2.4.6 idna-3.11 multitasking-0.0.12 peewee-3.18.2 protobuf-6.33.0 pycparser-2.23 requests-2.32.5 soupsieve-2.8 typing-extensions-4.15.0 urllib3-2.5.0 websockets-15.0.1 yfinance-0.2.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
from datetime import datetime, timedelta

# %%
ticker = "SPY"

t = yf.Ticker(ticker)

# %%
start = datetime(2021,1,1)
end = datetime(2025,6,1)

factor = 3

# %%
df = yf.download(ticker, start, end)
# Out:
# /var/folders/zh/4snkqr657fb06hs2r74_4xpm0000gn/T/ipykernel_34605/99250952.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.096619  130.189080  123.514467  130.101388  143301900
# 2021-01-05  127.655609  128.366929  125.141666  125.589894   97664900
# 2021-01-06  123.358521  127.694587  123.144152  124.449847  155088000
# 2021-01-07  127.567924  128.259752  124.586275  125.073473  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200

# %%
df['returns'] = df['Close'].pct_change()

# %%
df.head()
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.096619  130.189080  123.514467  130.101388  143301900
# 2021-01-05  127.655609  128.366929  125.141666  125.589894   97664900
# 2021-01-06  123.358521  127.694587  123.144152  124.449847  155088000
# 2021-01-07  127.567924  128.259752  124.586275  125.073473  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200
#
# Price        returns
# Ticker
# Date
# 2021-01-04       NaN
# 2021-01-05  0.012363
# 2021-01-06 -0.033662
# 2021-01-07  0.034123
# 2021-01-08  0.008631

# %%
import numpy as np

# %%
df['log_letf_factor'] = np.log(1 + df['returns']*factor)

# %%
df['log_ordinary_factor'] = np.log(1 + df['returns'])
df.drop(columns = ['log_ordinary_factor'])
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.096619  130.189080  123.514467  130.101388  143301900
# 2021-01-05  127.655609  128.366929  125.141666  125.589894   97664900
# 2021-01-06  123.358521  127.694587  123.144152  124.449847  155088000
# 2021-01-07  127.567924  128.259752  124.586275  125.073473  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200
# ...                ...         ...         ...         ...        ...
# 2025-05-23  195.048645  197.475883  193.240699  193.450453   78432900
# 2025-05-27  199.983047  200.512445  197.206185  198.075209   56288500
# 2025-05-28  200.192795  202.500174  199.673380  200.362600   45339700
# 2025-05-29  199.723328  203.578952  198.284958  203.349217   51396800
# 2025-05-30  200.622314  201.731057  196.556921  199.143981   70819900
#
# Price        returns log_letf_factor
# Ticker
# Date
# 2021-01-04       NaN             NaN
# 2021-01-05  0.012363        0.036419
# 2021-01-06 -0.033662       -0.106455
# 2021-01-07  0.034123        0.097462
# 2021-01-08  0.008631        0.025564
# ...              ...             ...
# 2025-05-23 -0.030244       -0.095116
# 2025-05-27  0.025298        0.073153
# 2025-05-28  0.001049        0.003142
# 2025-05-29 -0.002345       -0.007060
# 2025-05-30  0.004501        0.013413
#
# [1107 rows x 7 columns]

# %%
df.head()
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.096619  130.189080  123.514467  130.101388  143301900
# 2021-01-05  127.655609  128.366929  125.141666  125.589894   97664900
# 2021-01-06  123.358521  127.694587  123.144152  124.449847  155088000
# 2021-01-07  127.567924  128.259752  124.586275  125.073473  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200
#
# Price        returns log_letf_factor
# Ticker
# Date
# 2021-01-04       NaN             NaN
# 2021-01-05  0.012363        0.036419
# 2021-01-06 -0.033662       -0.106455
# 2021-01-07  0.034123        0.097462
# 2021-01-08  0.008631        0.025564

# %%
window_length = 10
window_start = datetime(2022,3,1)

# putting $100 into underlying

start_idx = df.index.get_loc(window_start)
end_idx = start_idx + window_length

# ordinary pct return ending on that day
df['ordinary_pct_return'] = 100*df['Close']/df['Close'].shift(window_length)

#ordinary_pct_change = 100*(df['Close'].iloc[end_idx]/df['Close'].iloc[start_idx])

df['leveraged_pct_change'] = 100*np.exp(df['log_letf_factor'].rolling(window = window_length).sum())

#leveraged_pct_change = 100*(np.exp(np.sum(df['log_letf_factor'].iloc[start_idx + 1: end_idx + 1])))

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.096619  130.189080  123.514467  130.101388  143301900
# 2021-01-05  127.655609  128.366929  125.141666  125.589894   97664900
# 2021-01-06  123.358521  127.694587  123.144152  124.449847  155088000
# 2021-01-07  127.567924  128.259752  124.586275  125.073473  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200
# ...                ...         ...         ...         ...        ...
# 2025-05-23  195.048645  197.475883  193.240699  193.450453   78432900
# 2025-05-27  199.983047  200.512445  197.206185  198.075209   56288500
# 2025-05-28  200.192795  202.500174  199.673380  200.362600   45339700
# 2025-05-29  199.723328  203.578952  198.284958  203.349217   51396800
# 2025-05-30  200.622314  201.731057  196.556921  199.143981   70819900
#
# Price        returns log_letf_factor log_ordinary_factor ordinary_pct_return  \
# Ticker
# Date
# 2021-01-04       NaN             NaN                 NaN                 NaN
# 2021-01-05  0.012363        0.036419            0.012288                 NaN
# 2021-01-06 -0.033662       -0.106455           -0.034241                 NaN
# 2021-01-07  0.034123        0.097462            0.033554                 NaN
# 2021-01-08  0.008631        0.025564            0.008594                 NaN
# ...              ...             ...                 ...                 ...
# 2025-05-23 -0.030244       -0.095116           -0.030711           98.486913
# 2025-05-27  0.025298        0.073153            0.024984           94.980793
# 2025-05-28  0.001049        0.003142            0.001048           94.124829
# 2025-05-29 -0.002345       -0.007060           -0.002348           94.169453
# 2025-05-30  0.004501        0.013413            0.004491           94.986995
#
# Price      leveraged_pct_change
# Ticker
# Date
# 2021-01-04                  NaN
# 2021-01-05                  NaN
# 2021-01-06                  NaN
# 2021-01-07                  NaN
# 2021-01-08                  NaN
# ...                         ...
# 2025-05-23            94.012344
# 2025-05-27            85.037945
# 2025-05-28            82.784171
# 2025-05-29            82.902580
# 2025-05-30            85.079887
#
# [1107 rows x 10 columns]

# %%
df.dropna(inplace = True)

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-19  124.557030  125.414503  123.689818  124.508307   90757300
# 2021-01-20  128.649506  129.097734  125.258612  125.365796  104319500
# 2021-01-21  133.365570  136.093882  130.169553  130.374182  120150900
# 2021-01-22  135.509262  136.269290  131.562955  132.790689  114459400
# 2021-01-25  139.260651  141.375088  133.044000  139.406819  157611700
# ...                ...         ...         ...         ...        ...
# 2025-05-23  195.048645  197.475883  193.240699  193.450453   78432900
# 2025-05-27  199.983047  200.512445  197.206185  198.075209   56288500
# 2025-05-28  200.192795  202.500174  199.673380  200.362600   45339700
# 2025-05-29  199.723328  203.578952  198.284958  203.349217   51396800
# 2025-05-30  200.622314  201.731057  196.556921  199.143981   70819900
#
# Price        returns log_letf_factor log_ordinary_factor ordinary_pct_return  \
# Ticker
# Date
# 2021-01-19  0.005427        0.016150            0.005412           98.779040
# 2021-01-20  0.032856        0.094008            0.032328          100.778576
# 2021-01-21  0.036658        0.104337            0.036002          108.112167
# 2021-01-22  0.016074        0.047095            0.015946          106.225184
# 2021-01-25  0.027684        0.079782            0.027307          108.231711
# ...              ...             ...                 ...                 ...
# 2025-05-23 -0.030244       -0.095116           -0.030711           98.486913
# 2025-05-27  0.025298        0.073153            0.024984           94.980793
# 2025-05-28  0.001049        0.003142            0.001048           94.124829
# 2025-05-29 -0.002345       -0.007060           -0.002348           94.169453
# 2025-05-30  0.004501        0.013413            0.004491           94.986995
#
# Price      leveraged_pct_change
# Ticker
# Date
# 2021-01-19            95.282084
# 2021-01-20           100.930371
# 2021-01-21           124.614301
# 2021-01-22           118.493226
# 2021-01-25           125.095028
# ...                         ...
# 2025-05-23            94.012344
# 2025-05-27            85.037945
# 2025-05-28            82.784171
# 2025-05-29            82.902580
# 2025-05-30            85.079887
#
# [1097 rows x 10 columns]

# %%
df['difference'] = df['leveraged_pct_change'] - df['ordinary_pct_return']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

plt.figure()
plt.hist(df['difference'], bins = 120)
plt.show()

# %%
df['difference'].quantile(0.95)
# Out:
# np.float64(19.01034401234276)

# %%
np.exp(np.sum(df['log_letf_factor'].iloc[start_idx+1:end_idx+1]))
# Out:
# np.float64(0.8438973806109844)

# %% [markdown]
# simulating movement GBM

# %%
import numpy as np

# %%
def simulate_gbm(S0, mu, sigma, T, N, n_paths):
    # simulate n_paths many paths from 0 to T of GBM with parameters mu and sigma
    dt = T/N
    times = np.linspace(0,T,N+1)

    Z = np.random.randn(n_paths,N)

    drift = mu - (1/2)*(sigma**2)*dt

# %%
    diffusion = sigma*dt*Z

    logS = np.zeros((n_paths, N+1))
    logS[:,0] = np.log(S0)
    logS[:, 1:] = np.cumsum(drift + diffusion, axis = 1) + logS[:,:1]

    S = np.exp(logS)

    return S

# %%
S = simulate_gbm(100,0.01,0.02,10,100,100)

# %%
import pandas as pd

# %%
df = pd.DataFrame(S)

# %%
df
# Out:
#       0           1           2           3           4           5    \
# 0   100.0  101.052128  102.386540  103.139004  104.238023  105.509953
# 1   100.0  100.858489  101.132101  102.045504  102.907436  103.621098
# 2   100.0  100.992713  102.026484  102.785158  103.634835  104.292525
# 3   100.0  101.143112  102.108015  103.198889  104.512350  105.754023
# 4   100.0  100.896286  101.710327  102.870181  104.138940  105.316189
# ..    ...         ...         ...         ...         ...         ...
# 95  100.0  100.652266  101.933683  102.622038  103.643274  104.436878
# 96  100.0  100.946334  102.097771  103.004145  104.129580  104.924591
# 97  100.0  100.848458  102.053123  103.287198  104.121371  104.921469
# 98  100.0  100.609905  101.835549  102.954638  104.425177  105.375419
# 99  100.0  100.620534  101.554974  102.638538  103.867380  104.938807
#
#            6           7           8           9    ...         91   \
# 0   106.786142  107.779487  108.819349  110.158454  ...  251.833865
# 1   104.607083  105.625565  106.649916  107.756408  ...  245.392569
# 2   105.249626  106.194559  107.063963  108.145334  ...  247.051620
# 3   106.938966  108.314967  110.056388  110.909679  ...  253.593194
# 4   106.385094  107.238334  108.483546  109.567969  ...  247.233915
# ..         ...         ...         ...         ...  ...         ...
# 95  105.610575  106.618959  107.807492  108.868620  ...  243.523815
# 96  105.935196  106.943808  107.759856  108.935826  ...  248.072286
# 97  105.886702  106.422733  107.418708  108.242266  ...  239.365790
# 98  106.334674  107.068857  108.103225  109.285553  ...  240.662711
# 99  106.132055  107.528769  108.720960  109.881347  ...  243.089640
#
#            92          93          94          95          96          97   \
# 0   253.976300  257.321826  260.606751  263.629457  266.392384  269.673751
# 1   248.141576  250.822772  253.381943  255.758368  258.093229  261.053374
# 2   248.885621  251.657043  254.016080  255.903678  257.050202  259.695458
# 3   255.984416  258.773483  261.669526  265.077718  267.520239  270.560734
# 4   250.122543  252.959112  255.955442  259.299161  262.291394  264.939962
# ..         ...         ...         ...         ...         ...         ...
# 95  245.688159  248.865599  251.500632  253.708078  255.583192  258.036925
# 96  250.420763  253.632329  256.095758  258.688588  261.757160  264.674883
# 97  241.560379  243.936924  247.147535  249.527658  252.028929  255.159988
# 98  242.773521  245.577816  248.414915  250.876810  253.596586  256.428868
# 99  246.233117  248.782214  251.239102  253.499371  257.341621  260.459284
#
#            98          99          100
# 0   272.864762  275.306776  278.094615
# 1   263.581516  265.768556  268.508739
# 2   262.108548  264.054603  266.445130
# 3   273.852523  276.433237  278.598668
# 4   267.587108  270.252748  273.979610
# ..         ...         ...         ...
# 95  260.088024  262.714916  265.873591
# 96  268.025049  271.009716  273.446947
# 97  257.690935  259.929316  262.663815
# 98  258.375445  260.940818  263.786450
# 99  262.755839  264.853167  267.711462
#
# [100 rows x 101 columns]

# %% [markdown]
# now do the below but with the above S

# %%
# ordinary pct return ending on that day
df['ordinary_pct_return'] = 100*df['Close']/df['Close'].shift(window_length)

#ordinary_pct_change = 100*(df['Close'].iloc[end_idx]/df['Close'].iloc[start_idx])

df['leveraged_pct_change'] = 100*np.exp(df['log_letf_factor'].rolling(window = window_length).sum())

#leveraged_pct_change = 100*(np.exp(np.sum(df['log_letf_factor'].iloc[start_idx + 1: end_idx + 1])))
